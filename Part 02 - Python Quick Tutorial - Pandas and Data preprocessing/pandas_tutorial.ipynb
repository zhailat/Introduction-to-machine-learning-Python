# %% [markdown]
# # Python Tutorial - Pandas

# %% [markdown]
# ## Install pandas
# ### After you cativate your environment, "Open Terminal" then type
# #### pip install pandas

# %% [markdown]
# ## Search for and download the publicly available house pricing dataset.

# %%
import pandas as pd
import numpy as np

# %%
# house_ds = pd.read_excel('house_price_ds.xlsx')
# house_ds = pd.read_csv(r'/home/files/tutorial/house_price_ds.csv')
house_ds = pd.read_csv('house_price_ds.csv')

# %%
house_ds.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_ds.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
v1 = house_ds.tail(10)
v1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
house_ds.iloc[10] # select by position (row)
# Out:
# Id                   11
# MSSubClass           20
# MSZoning             RL
# LotFrontage          70
# LotArea           11200
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        129500
# Name: 10, Length: 81, dtype: object

# %%
house_ds.loc[10] # select by index
# Out:
# Id                   11
# MSSubClass           20
# MSZoning             RL
# LotFrontage          70
# LotArea           11200
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        129500
# Name: 10, Length: 81, dtype: object

# %%
house_ds.iloc[0,:] # select first row
# Out:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage          65
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object

# %%
house_ds.iloc[0,0] # select element from first row
# Out:
# 1

# %%
print(f'number of training examples = {len(house_ds)}')
# Out:
# number of training examples = 1460

# %%
house_ds.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
house_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_ds['YearBuilt']
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
house_ds.YearBuilt
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
# house_ds.Date = pd.to_datetime(house_ds.Date)
# house_ds['new_date'] = pd.to_datetime(house_ds.Date)

house_ds.Id  = house_ds.Id.astype(int)
house_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
for idx, col in enumerate(house_ds.columns):
    print(idx, ' ', col)
# Out:
# 0   Id
# 1   MSSubClass
# 2   MSZoning
# 3   LotFrontage
# 4   LotArea
# 5   Street
# 6   Alley
# 7   LotShape
# 8   LandContour
# 9   Utilities
# 10   LotConfig
# 11   LandSlope
# 12   Neighborhood
# 13   Condition1
# 14   Condition2
# 15   BldgType
# 16   HouseStyle
# 17   OverallQual
# 18   OverallCond
# 19   YearBuilt
# 20   YearRemodAdd
# 21   RoofStyle
# 22   RoofMatl
# 23   Exterior1st
# 24   Exterior2nd
# 25   MasVnrType
# 26   MasVnrArea
# 27   ExterQual
# 28   ExterCond
# 29   Foundation
# 30   BsmtQual
# 31   BsmtCond
# 32   BsmtExposure
# 33   BsmtFinType1
# 34   BsmtFinSF1
# 35   BsmtFinType2
# 36   BsmtFinSF2
# 37   BsmtUnfSF
# 38   TotalBsmtSF
# 39   Heating
# 40   HeatingQC
# 41   CentralAir
# 42   Electrical
# 43   1stFlrSF
# 44   2ndFlrSF
# 45   LowQualFinSF
# 46   GrLivArea
# 47   BsmtFullBath
# 48   BsmtHalfBath
# 49   FullBath
# 50   HalfBath
# 51   BedroomAbvGr
# 52   KitchenAbvGr
# 53   KitchenQual
# 54   TotRmsAbvGrd
# 55   Functional
# 56   Fireplaces
# ...

# %%
na_stat = house_ds.isna().sum()
# isnull()
na_stat
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print(f'number of training examples = {len(house_ds)}')
# house_ds = house_ds.dropna()
# print(f'number of training examples after dropna() = {len(house_ds)}')
# Out:
# number of training examples = 1460

# %%
house_ds = house_ds.fillna(-1)
print(f'number of training examples = {len(house_ds)}')
# Out:
# number of training examples = 1460

# %%
house_ds.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
# house_ds.mean(axis=0) # columns
# house_ds.mean(axis=1) # rows
# house_ds.std(axis=0)
# house_ds.max()
# house_ds.min()
# Out:
# Id                  1460
# MSSubClass           190
# MSZoning              RM
# LotFrontage          313
# LotArea           215245
#                   ...
# MoSold                12
# YrSold              2010
# SaleType              WD
# SaleCondition    Partial
# SalePrice         755000
# Length: 65, dtype: object

# %%
house_ds_2 = house_ds[[
    'LotArea',
    'BedroomAbvGr',
    'SalePrice'
]]
house_ds_2.head()
# Out:
#    LotArea  BedroomAbvGr  SalePrice
# 0     8450             3     208500
# 1     9600             3     181500
# 2    11250             3     223500
# 3     9550             3     140000
# 4    14260             4     250000

# %%
house_ds_2.max()
# Out:
# LotArea         215245
# BedroomAbvGr         8
# SalePrice       755000
# dtype: int64

# %%
house_ds_2.min()
# Out:
# LotArea          1300
# BedroomAbvGr        0
# SalePrice       34900
# dtype: int64

# %%
house_ds_norm1 = house_ds_2 / house_ds_2.max()
house_ds_norm1
# Out:
#        LotArea  BedroomAbvGr  SalePrice
# 0     0.039258         0.375   0.276159
# 1     0.044600         0.375   0.240397
# 2     0.052266         0.375   0.296026
# 3     0.044368         0.375   0.185430
# 4     0.066250         0.500   0.331126
# ...        ...           ...        ...
# 1455  0.036781         0.375   0.231788
# 1456  0.061209         0.375   0.278146
# 1457  0.042008         0.500   0.352980
# 1458  0.045144         0.250   0.188245
# 1459  0.046166         0.375   0.195364
#
# [1460 rows x 3 columns]

# %%
house_ds_norm1.max()
# Out:
# LotArea         1.0
# BedroomAbvGr    1.0
# SalePrice       1.0
# dtype: float64

# %%
house_ds_norm1.min()
# Out:
# LotArea         0.006040
# BedroomAbvGr    0.000000
# SalePrice       0.046225
# dtype: float64

# %%
house_ds_mean_norm1 = (house_ds_2 - house_ds_2.mean() ) / (house_ds_2.max() - house_ds_2.min() )
house_ds_mean_norm1
# Out:
#        LotArea  BedroomAbvGr  SalePrice
# 0    -0.009661      0.016695   0.038299
# 1    -0.004285      0.016695   0.000804
# 2     0.003427      0.016695   0.059129
# 3    -0.004519      0.016695  -0.056827
# 4     0.017496      0.141695   0.095929
# ...        ...           ...        ...
# 1455 -0.012152      0.016695  -0.008223
# 1456  0.012425      0.016695   0.040382
# 1457 -0.006893      0.141695   0.118843
# 1458 -0.003738     -0.108305  -0.053876
# 1459 -0.002710      0.016695  -0.046412
#
# [1460 rows x 3 columns]

# %%
house_ds_mean_norm1.max()
# Out:
# LotArea         0.956920
# BedroomAbvGr    0.641695
# SalePrice       0.797221
# dtype: float64

# %%
house_ds_mean_norm1.min()
# Out:
# LotArea        -0.043080
# BedroomAbvGr   -0.358305
# SalePrice      -0.202779
# dtype: float64

# %%
house_ds_mean_norm2 = (house_ds_2 - house_ds_2.mean() ) / house_ds_2.std() 
house_ds_mean_norm2
# Out:
#        LotArea  BedroomAbvGr  SalePrice
# 0    -0.207071      0.163723   0.347154
# 1    -0.091855      0.163723   0.007286
# 2     0.073455      0.163723   0.535970
# 3    -0.096864      0.163723  -0.515105
# 4     0.375020      1.389547   0.869545
# ...        ...           ...        ...
# 1455 -0.260471      0.163723  -0.074534
# 1456  0.266316      0.163723   0.366036
# 1457 -0.147760      1.389547   1.077242
# 1458 -0.080133     -1.062101  -0.488356
# 1459 -0.058092      0.163723  -0.420697
#
# [1460 rows x 3 columns]

# %%
t = house_ds_mean_norm2.max()
print(house_ds_mean_norm2.min())
# Out:
# LotArea        -0.923413
# BedroomAbvGr   -3.513748
# SalePrice      -1.838074
# dtype: float64

# %%
house_ds_mean_norm2.to_csv('house_mean_normalized.csv', index=False, header=True)
house_ds_mean_norm2.to_excel('house_mean_normalized.xlsx', index=False, header=True)

# %%
house_ds_mean_norm2 = house_ds_mean_norm2.sort_values(by=['LotArea', 'SalePrice'])
house_ds_mean_norm2
# Out:
#         LotArea  BedroomAbvGr  SalePrice
# 956   -0.923413     -1.062101  -0.716508
# 1039  -0.905680     -2.287924  -1.270368
# 614   -0.904277     -2.287924  -1.327013
# 489   -0.900770     -2.287924  -1.194841
# 1449  -0.900069     -2.287924  -1.119315
# ...         ...           ...        ...
# 451    6.035725     -1.062101   1.247176
# 706   10.482857     -1.062101   1.524106
# 249   14.876188      1.389547   1.209413
# 335   15.443250      0.163723   0.604573
# 313   20.511245      0.163723   2.443010
#
# [1460 rows x 3 columns]

# %%
house_ds_mean_norm2 = house_ds_mean_norm2.reset_index(drop=True)
house_ds_mean_norm2
# Out:
#         LotArea  BedroomAbvGr  SalePrice
# 0     -0.923413     -1.062101  -0.716508
# 1     -0.905680     -2.287924  -1.270368
# 2     -0.904277     -2.287924  -1.327013
# 3     -0.900770     -2.287924  -1.194841
# 4     -0.900069     -2.287924  -1.119315
# ...         ...           ...        ...
# 1455   6.035725     -1.062101   1.247176
# 1456  10.482857     -1.062101   1.524106
# 1457  14.876188      1.389547   1.209413
# 1458  15.443250      0.163723   0.604573
# 1459  20.511245      0.163723   2.443010
#
# [1460 rows x 3 columns]

# %%
house_ds_mean_norm2 = house_ds_mean_norm2.drop_duplicates()

# %%
new_empty_df = pd.DataFrame()
new_empty_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
np_array = np.array(['a', 'b', 'c', 'd'])
np_array
# Out:
# array(['a', 'b', 'c', 'd'], dtype='<U1')

# %%
# convert numpy to pandas dataframe.
a_df = pd.DataFrame(np_array)
a_df
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d
